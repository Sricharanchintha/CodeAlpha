# %%
# !pip install playwright beautifulsoup4 pandas openpyxl lxml -q
# !playwright install chromium

# %%
import asyncio
import nest_asyncio
nest_asyncio.apply()

from playwright.async_api import async_playwright
from bs4 import BeautifulSoup
import pandas as pd
import time

all_jobs = []

async def scrape_all_pages():
    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=False)  # Change to True after testing
        context = await browser.new_context(
            viewport={'width': 1920, 'height': 1080},
            user_agent="Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36"
        )
        
        # Stealth script — bypasses Cloudflare & captcha
        await context.add_init_script("""
            Object.defineProperty(navigator, 'webdriver', {get: () => false});
            window.chrome = { runtime: {} };
        """)
        
        page = await context.new_page()
        
        # Start with page 1
        current_page = 1
        while True:
            url = f"https://www.naukri.com/data-analyst-data-analytics-data-analysis-data-visualization-data-cleansing-jobs?k=data%20analyst%2C%20data%20analytics%2C%20data%20analysis%2C%20data%20visualization%2C%20data%20cleansing&experience=0&ugTypeGid=12&jobPostType=1&glbl_qcrc=1018&glbl_qcrc=1020&pageNo={current_page}"
            
            print(f"Scraping page {current_page}...")
            await page.goto(url, wait_until="domcontentloaded", timeout=60000)
            
            try:
                await page.wait_for_selector('a[title]', timeout=30000)  # any job title
            except:
                print("No more jobs or blocked — stopping")
                break
                
            # Human-like scroll
            await page.evaluate("window.scrollTo(0, document.body.scrollHeight)")
            await asyncio.sleep(3)
            
            html = await page.content()
            soup = BeautifulSoup(html, 'lxml')
            
            # Multiple selector fallback (Naukri changes class names)
            jobs = soup.find_all('div', class_='srp-jobtuple-wrapper') or \
                    soup.find_all('div', class_='jobTuple') or \
                    soup.find_all('li', class_=lambda x: x and 'jobTuple' in str(x))
            
            if len(jobs) == 0:
                print("No jobs found on this page → end of results")
                break
                
            print(f"   → Found {len(jobs)} jobs on page {current_page}")
            
            for job in jobs:
                try:
                    title_tag = job.find('a', class_='title') or job.find('a', {'data-automation': 'jobTitle'})
                    title = title_tag.get('title') or title_tag.get_text(strip=True) if title_tag else 'N/A'
                    link = title_tag['href'] if title_tag and title_tag.get('href') else 'N/A'
                    if link != 'N/A' and not link.startswith('http'):
                        link = 'https://www.naukri.com' + link
                        
                    company = (job.find('a', class_='comp-name') or 
                              job.find('span', {'data-automation': 'jobCompany'}))
                    company = company.get_text(strip=True) if company else 'N/A'
                    
                    location = (job.find('span', class_='locWdth') or 
                               job.find('span', {'data-automation': 'jobLocation'}))
                    location = location.get_text(strip=True) if location else 'N/A'
                    
                    exp = (job.find('span', class_='expwdth') or 
                          job.find('span', {'data-automation': 'jobExperience'}))
                    exp = exp.get_text(strip=True) if exp else 'N/A'
                    
                    salary = (job.find('span', class_='sal') or 
                             job.find('span', {'data-automation': 'jobSalary'}))
                    salary = salary.get_text(strip=True) if salary else 'Not Disclosed'
                    
                    all_jobs.append({
                        'Job Title': title,
                        'Company': company,
                        'Location': location,
                        'Experience': exp,
                        'Salary': salary,
                        'Link': link
                    })
                except:
                    continue  # skip broken job cards
            
            current_page += 1
            await asyncio.sleep(5)  # Be respectful
            
        await browser.close()

# RUN THE SCRAPER
print("Starting full scrape — this will take 4–8 minutes for 400–500 jobs...")
asyncio.get_event_loop().run_until_complete(scrape_all_pages())

# Save to Excel
df = pd.DataFrame(all_jobs)
df.to_excel('ALL_Fresher_Data_Analyst_Jobs_Naukri_Nov2025.xlsx', index=False)
df.to_csv('ALL_Fresher_Data_Analyst_Jobs_Naukri_Nov2025.csv', index=False)

print(f"\nDONE! Scraped {len(df)} jobs from {len(set(df['Link']))} unique listings")
print("Files saved:")
print("   → ALL_Fresher_Data_Analyst_Jobs_Naukri_Nov2025.xlsx")
print("   → ALL_Fresher_Data_Analyst_Jobs_Naukri_Nov2025.csv")
df.head(10)
# Out:
# Starting full scrape — this will take 4–8 minutes for 400–500 jobs...
# Scraping page 1...
#    → Found 20 jobs on page 1
# Scraping page 2...
#    → Found 20 jobs on page 2
# Scraping page 3...
#    → Found 20 jobs on page 3
# Scraping page 4...
#    → Found 20 jobs on page 4
# Scraping page 5...
#    → Found 20 jobs on page 5
# Scraping page 6...
#    → Found 20 jobs on page 6
# Scraping page 7...
#    → Found 20 jobs on page 7
# Scraping page 8...
#    → Found 20 jobs on page 8
# Scraping page 9...
#    → Found 20 jobs on page 9
# Scraping page 10...
#    → Found 20 jobs on page 10
# Scraping page 11...
#    → Found 20 jobs on page 11
# Scraping page 12...
#    → Found 20 jobs on page 12
# Scraping page 13...
#    → Found 20 jobs on page 13
# Scraping page 14...
#    → Found 20 jobs on page 14
# Scraping page 15...
#    → Found 20 jobs on page 15
# Scraping page 16...
#    → Found 20 jobs on page 16
# Scraping page 17...
#    → Found 20 jobs on page 17
# Scraping page 18...
#    → Found 20 jobs on page 18
# Scraping page 19...
#    → Found 20 jobs on page 19
# Scraping page 20...
#    → Found 20 jobs on page 20
# Scraping page 21...
#    → Found 20 jobs on page 21
# Scraping page 22...
#    → Found 20 jobs on page 22
# Scraping page 23...
#    → Found 20 jobs on page 23
# Scraping page 24...
#    → Found 20 jobs on page 24
# Scraping page 25...
#    → Found 20 jobs on page 25
# Scraping page 26...
#    → Found 20 jobs on page 26
# Scraping page 27...
#    → Found 20 jobs on page 27
# Scraping page 28...
#    → Found 20 jobs on page 28
# Scraping page 29...
#    → Found 20 jobs on page 29
# Scraping page 30...
#    → Found 20 jobs on page 30
# Scraping page 31...
#    → Found 20 jobs on page 31
# Scraping page 32...
#    → Found 20 jobs on page 32
# Scraping page 33...
#    → Found 20 jobs on page 33
# Scraping page 34...
#    → Found 20 jobs on page 34
# Scraping page 35...
#    → Found 20 jobs on page 35
# Scraping page 36...
#    → Found 20 jobs on page 36
# Scraping page 37...
#    → Found 20 jobs on page 37
# Scraping page 38...
#    → Found 20 jobs on page 38
# Scraping page 39...
#    → Found 20 jobs on page 39
# Scraping page 40...
#    → Found 20 jobs on page 40
# Scraping page 41...
#    → Found 20 jobs on page 41
# Scraping page 42...
#    → Found 20 jobs on page 42
# Scraping page 43...
#    → Found 20 jobs on page 43
# Scraping page 44...
#    → Found 20 jobs on page 44
# Scraping page 45...
#    → Found 20 jobs on page 45
# Scraping page 46...
#    → Found 20 jobs on page 46
# Scraping page 47...
#    → Found 20 jobs on page 47
# Scraping page 48...
#    → Found 20 jobs on page 48
# Scraping page 49...
#    → Found 20 jobs on page 49
# Scraping page 50...
#    → Found 20 jobs on page 50
# Scraping page 51...
#    → Found 20 jobs on page 51
# Scraping page 52...
#    → Found 20 jobs on page 52
# Scraping page 53...
#    → Found 20 jobs on page 53
# Scraping page 54...
#    → Found 20 jobs on page 54
# Scraping page 55...
#    → Found 20 jobs on page 55
# Scraping page 56...
#    → Found 20 jobs on page 56
# Scraping page 57...
#    → Found 20 jobs on page 57
# Scraping page 58...
#    → Found 20 jobs on page 58
# Scraping page 59...
#    → Found 20 jobs on page 59
# Scraping page 60...
#    → Found 20 jobs on page 60
# Scraping page 61...
#    → Found 20 jobs on page 61
# Scraping page 62...
#    → Found 20 jobs on page 62
# Scraping page 63...
#    → Found 20 jobs on page 63
# Scraping page 64...
#    → Found 20 jobs on page 64
# Scraping page 65...
#    → Found 20 jobs on page 65
# Scraping page 66...
#    → Found 20 jobs on page 66
# Scraping page 67...
#    → Found 20 jobs on page 67
# Scraping page 68...
#    → Found 20 jobs on page 68
# Scraping page 69...
#    → Found 20 jobs on page 69
# Scraping page 70...
#    → Found 20 jobs on page 70
# Scraping page 71...
#    → Found 20 jobs on page 71
# Scraping page 72...
#    → Found 20 jobs on page 72
# Scraping page 73...
#    → Found 20 jobs on page 73
# Scraping page 74...
#    → Found 20 jobs on page 74
# Scraping page 75...
#    → Found 20 jobs on page 75
# Scraping page 76...
#    → Found 20 jobs on page 76
# Scraping page 77...
#    → Found 20 jobs on page 77
# Scraping page 78...
#    → Found 20 jobs on page 78
# Scraping page 79...
#    → Found 20 jobs on page 79
# Scraping page 80...
#    → Found 20 jobs on page 80
# Scraping page 81...
#    → Found 20 jobs on page 81
# Scraping page 82...
#    → Found 20 jobs on page 82
# Scraping page 83...
#    → Found 20 jobs on page 83
# Scraping page 84...
#    → Found 20 jobs on page 84
# Scraping page 85...
#    → Found 20 jobs on page 85
# Scraping page 86...
#    → Found 20 jobs on page 86
# Scraping page 87...
#    → Found 20 jobs on page 87
# Scraping page 88...
#    → Found 20 jobs on page 88
# Scraping page 89...
#    → Found 20 jobs on page 89
# Scraping page 90...
#    → Found 20 jobs on page 90
# Scraping page 91...
#    → Found 20 jobs on page 91
# Scraping page 92...
#    → Found 20 jobs on page 92
# Scraping page 93...
#    → Found 20 jobs on page 93
# Scraping page 94...
#    → Found 20 jobs on page 94
# Scraping page 95...
#    → Found 20 jobs on page 95
# Scraping page 96...
#    → Found 20 jobs on page 96
# Scraping page 97...
#    → Found 20 jobs on page 97
# Scraping page 98...
#    → Found 20 jobs on page 98
# Scraping page 99...
#    → Found 20 jobs on page 99
# Scraping page 100...
#    → Found 20 jobs on page 100
# Scraping page 101...
#    → Found 20 jobs on page 101
# Scraping page 102...
#    → Found 20 jobs on page 102
# Scraping page 103...
#    → Found 20 jobs on page 103
# Scraping page 104...
#    → Found 20 jobs on page 104
# Scraping page 105...
#    → Found 20 jobs on page 105
# Scraping page 106...
#    → Found 20 jobs on page 106
# Scraping page 107...
#    → Found 20 jobs on page 107
# Scraping page 108...
#    → Found 20 jobs on page 108
# Scraping page 109...
#    → Found 20 jobs on page 109
# Scraping page 110...
#    → Found 20 jobs on page 110
# Scraping page 111...
#    → Found 20 jobs on page 111
# Scraping page 112...
#    → Found 20 jobs on page 112
# Scraping page 113...
#    → Found 20 jobs on page 113
# Scraping page 114...
#    → Found 20 jobs on page 114
# Scraping page 115...
#    → Found 20 jobs on page 115
# Scraping page 116...
#    → Found 20 jobs on page 116
# Scraping page 117...
#    → Found 20 jobs on page 117
# Scraping page 118...
#    → Found 20 jobs on page 118
# Scraping page 119...
#    → Found 9 jobs on page 119
# Scraping page 120...
#    → Found 20 jobs on page 120
# Scraping page 121...
#    → Found 20 jobs on page 121
# Scraping page 122...
#    → Found 20 jobs on page 122
# Scraping page 123...
#    → Found 20 jobs on page 123
# Scraping page 124...
#    → Found 20 jobs on page 124
# Scraping page 125...
#    → Found 20 jobs on page 125
# Scraping page 126...
#    → Found 20 jobs on page 126
# Scraping page 127...
#    → Found 20 jobs on page 127
# Scraping page 128...
#    → Found 20 jobs on page 128
# Scraping page 129...
#    → Found 20 jobs on page 129
# Scraping page 130...
#    → Found 20 jobs on page 130
# Scraping page 131...
#    → Found 20 jobs on page 131
# Scraping page 132...
#    → Found 20 jobs on page 132
# Scraping page 133...
#    → Found 20 jobs on page 133
# Scraping page 134...
#    → Found 20 jobs on page 134
# Scraping page 135...
#    → Found 20 jobs on page 135
# Scraping page 136...
#    → Found 20 jobs on page 136
# Scraping page 137...
#    → Found 20 jobs on page 137
# Scraping page 138...
#    → Found 20 jobs on page 138
# Scraping page 139...
#    → Found 20 jobs on page 139
# Scraping page 140...
#    → Found 20 jobs on page 140
# Scraping page 141...
#    → Found 20 jobs on page 141
# Scraping page 142...
#    → Found 20 jobs on page 142
# Scraping page 143...
#    → Found 20 jobs on page 143
# Scraping page 144...
#    → Found 20 jobs on page 144
# Scraping page 145...
#    → Found 20 jobs on page 145
# Scraping page 146...
#    → Found 20 jobs on page 146
# Scraping page 147...
#    → Found 20 jobs on page 147
# Scraping page 148...
#    → Found 20 jobs on page 148
# Scraping page 149...
#    → Found 20 jobs on page 149
# Scraping page 150...
#    → Found 20 jobs on page 150
# Scraping page 151...
#    → Found 20 jobs on page 151
# Scraping page 152...
#    → Found 20 jobs on page 152
# Scraping page 153...
#    → Found 20 jobs on page 153
# Scraping page 154...
#    → Found 20 jobs on page 154
# Scraping page 155...
#    → Found 20 jobs on page 155
# Scraping page 156...
#    → Found 20 jobs on page 156
# Scraping page 157...
#    → Found 20 jobs on page 157
# Scraping page 158...
#    → Found 20 jobs on page 158
# Scraping page 159...
#    → Found 20 jobs on page 159
# Scraping page 160...
#    → Found 20 jobs on page 160
# Scraping page 161...
#    → Found 20 jobs on page 161
# Scraping page 162...
#    → Found 20 jobs on page 162
# Scraping page 163...
#    → Found 20 jobs on page 163
# Scraping page 164...
#    → Found 20 jobs on page 164
# Scraping page 165...
#    → Found 20 jobs on page 165
# Scraping page 166...
#    → Found 20 jobs on page 166
# Scraping page 167...
#    → Found 20 jobs on page 167
# Scraping page 168...
#    → Found 20 jobs on page 168
# Scraping page 169...
#    → Found 20 jobs on page 169
# Scraping page 170...
#    → Found 20 jobs on page 170
# Scraping page 171...
#    → Found 20 jobs on page 171
# Scraping page 172...
#    → Found 20 jobs on page 172
# Scraping page 173...
#    → Found 20 jobs on page 173
# Scraping page 174...
#    → Found 20 jobs on page 174
# Scraping page 175...
#    → Found 20 jobs on page 175
# Scraping page 176...
#    → Found 20 jobs on page 176
# Scraping page 177...
#    → Found 20 jobs on page 177
# Scraping page 178...
#    → Found 20 jobs on page 178
# Scraping page 179...
#    → Found 20 jobs on page 179
# Scraping page 180...
#    → Found 20 jobs on page 180
# Scraping page 181...
#    → Found 20 jobs on page 181
# Scraping page 182...
#    → Found 20 jobs on page 182
# Scraping page 183...
#    → Found 20 jobs on page 183
# Scraping page 184...
#    → Found 20 jobs on page 184
# Scraping page 185...
#    → Found 20 jobs on page 185
# Scraping page 186...
#    → Found 20 jobs on page 186
# Scraping page 187...
#    → Found 20 jobs on page 187
# Scraping page 188...
#    → Found 20 jobs on page 188
# Scraping page 189...
#    → Found 20 jobs on page 189
# Scraping page 190...
#    → Found 20 jobs on page 190
# Scraping page 191...
#    → Found 20 jobs on page 191
# Scraping page 192...
#    → Found 20 jobs on page 192
# Scraping page 193...
#    → Found 20 jobs on page 193
# Scraping page 194...
#    → Found 20 jobs on page 194
# Scraping page 195...
#    → Found 20 jobs on page 195
# Scraping page 196...
#    → Found 20 jobs on page 196
# Scraping page 197...
#    → Found 20 jobs on page 197
# Scraping page 198...
#    → Found 20 jobs on page 198
# Scraping page 199...
#    → Found 20 jobs on page 199
# Scraping page 200...
#    → Found 20 jobs on page 200
# Scraping page 201...
#    → Found 20 jobs on page 201
# Scraping page 202...
#    → Found 20 jobs on page 202
# Scraping page 203...
#    → Found 20 jobs on page 203
# Scraping page 204...
#    → Found 20 jobs on page 204
# Scraping page 205...
#    → Found 20 jobs on page 205
# Scraping page 206...
#    → Found 20 jobs on page 206
# Scraping page 207...
#    → Found 20 jobs on page 207
# Scraping page 208...
#    → Found 20 jobs on page 208
# Scraping page 209...
#    → Found 20 jobs on page 209
# Scraping page 210...
#    → Found 20 jobs on page 210
# Scraping page 211...
#    → Found 20 jobs on page 211
# Scraping page 212...
#    → Found 20 jobs on page 212
# Scraping page 213...
#    → Found 20 jobs on page 213
# Scraping page 214...
#    → Found 20 jobs on page 214
# Scraping page 215...
#    → Found 20 jobs on page 215
# Scraping page 216...
#    → Found 20 jobs on page 216
# Scraping page 217...
#    → Found 20 jobs on page 217
# Scraping page 218...
#    → Found 20 jobs on page 218
# Scraping page 219...
#    → Found 20 jobs on page 219
# Scraping page 220...
#    → Found 20 jobs on page 220
# Scraping page 221...
#    → Found 20 jobs on page 221
# Scraping page 222...
#    → Found 20 jobs on page 222
# Scraping page 223...
#    → Found 20 jobs on page 223
# Scraping page 224...
#    → Found 20 jobs on page 224
# Scraping page 225...
#    → Found 20 jobs on page 225
# Scraping page 226...
#    → Found 20 jobs on page 226
# Scraping page 227...
#    → Found 20 jobs on page 227
# Scraping page 228...
#    → Found 20 jobs on page 228
# Scraping page 229...
#    → Found 20 jobs on page 229
# Scraping page 230...
#    → Found 20 jobs on page 230
# Scraping page 231...
#    → Found 20 jobs on page 231
# Scraping page 232...
#    → Found 20 jobs on page 232
# Scraping page 233...
#    → Found 20 jobs on page 233
# Scraping page 234...
#    → Found 20 jobs on page 234
# Scraping page 235...
#    → Found 20 jobs on page 235
# Scraping page 236...
#    → Found 20 jobs on page 236
# Scraping page 237...
#    → Found 20 jobs on page 237
# Scraping page 238...
#    → Found 20 jobs on page 238
# Scraping page 239...
#    → Found 20 jobs on page 239
# Scraping page 240...
#    → Found 20 jobs on page 240
# Scraping page 241...
#    → Found 20 jobs on page 241
# Scraping page 242...
#    → Found 20 jobs on page 242
# Scraping page 243...
#    → Found 20 jobs on page 243
# Scraping page 244...
#    → Found 20 jobs on page 244
# Scraping page 245...
#    → Found 20 jobs on page 245
# Scraping page 246...
#    → Found 20 jobs on page 246
# Scraping page 247...
#    → Found 20 jobs on page 247
# Scraping page 248...
#    → Found 20 jobs on page 248
# Scraping page 249...
#    → Found 20 jobs on page 249
# Scraping page 250...
#    → Found 20 jobs on page 250
# Scraping page 251...
#    → Found 20 jobs on page 251
# Scraping page 252...
#    → Found 20 jobs on page 252
# Scraping page 253...
#    → Found 20 jobs on page 253
# Scraping page 254...
#    → Found 20 jobs on page 254
# Scraping page 255...
#    → Found 20 jobs on page 255
# Scraping page 256...
#    → Found 20 jobs on page 256
# Scraping page 257...
#    → Found 20 jobs on page 257
# Scraping page 258...
#    → Found 20 jobs on page 258
# Scraping page 259...
#    → Found 20 jobs on page 259
# Scraping page 260...
#    → Found 20 jobs on page 260
# Scraping page 261...
#    → Found 20 jobs on page 261
# Scraping page 262...
#    → Found 20 jobs on page 262
# Scraping page 263...
#    → Found 20 jobs on page 263
# Scraping page 264...
#    → Found 20 jobs on page 264
# Scraping page 265...
#    → Found 20 jobs on page 265
# Scraping page 266...
#    → Found 20 jobs on page 266
# Scraping page 267...
#    → Found 20 jobs on page 267
# Scraping page 268...
#    → Found 20 jobs on page 268
# Scraping page 269...
#    → Found 20 jobs on page 269
# Scraping page 270...
#    → Found 20 jobs on page 270
# Scraping page 271...
#    → Found 20 jobs on page 271
# Scraping page 272...
#    → Found 20 jobs on page 272
# Scraping page 273...
#    → Found 20 jobs on page 273
# Scraping page 274...
#    → Found 20 jobs on page 274
# Scraping page 275...
#    → Found 20 jobs on page 275
# Scraping page 276...
#    → Found 20 jobs on page 276
# Scraping page 277...
#    → Found 20 jobs on page 277
# Scraping page 278...
#    → Found 20 jobs on page 278
# Scraping page 279...
#    → Found 20 jobs on page 279
# Scraping page 280...
#    → Found 20 jobs on page 280
# Scraping page 281...
#    → Found 20 jobs on page 281
# Scraping page 282...
#    → Found 20 jobs on page 282
# Scraping page 283...
#    → Found 20 jobs on page 283
# Scraping page 284...
#    → Found 20 jobs on page 284
# Scraping page 285...
#    → Found 20 jobs on page 285
# Scraping page 286...
#    → Found 20 jobs on page 286
# Scraping page 287...
#    → Found 20 jobs on page 287
# Scraping page 288...
#    → Found 20 jobs on page 288
# Scraping page 289...
#    → Found 20 jobs on page 289
# Scraping page 290...
#    → Found 20 jobs on page 290
# Scraping page 291...
#    → Found 20 jobs on page 291
# Scraping page 292...
#    → Found 20 jobs on page 292
# Scraping page 293...
#    → Found 20 jobs on page 293
# Scraping page 294...
#    → Found 20 jobs on page 294
# Scraping page 295...
#    → Found 20 jobs on page 295
# Scraping page 296...
#    → Found 20 jobs on page 296
# Scraping page 297...
#    → Found 20 jobs on page 297
# Scraping page 298...
#    → Found 20 jobs on page 298
# Scraping page 299...
#    → Found 20 jobs on page 299
# Scraping page 300...
#    → Found 20 jobs on page 300
# Scraping page 301...
#    → Found 20 jobs on page 301
# Scraping page 302...
#    → Found 20 jobs on page 302
# Scraping page 303...
#    → Found 20 jobs on page 303
# Scraping page 304...
#    → Found 20 jobs on page 304
# Scraping page 305...
#    → Found 20 jobs on page 305
# Scraping page 306...
#    → Found 20 jobs on page 306
# Scraping page 307...
#    → Found 20 jobs on page 307
# Scraping page 308...
#    → Found 20 jobs on page 308
# Scraping page 309...
#    → Found 20 jobs on page 309
# Scraping page 310...
#    → Found 20 jobs on page 310
# Scraping page 311...
#    → Found 20 jobs on page 311
# Scraping page 312...
#    → Found 20 jobs on page 312
# Scraping page 313...
#    → Found 20 jobs on page 313
# Scraping page 314...
#    → Found 20 jobs on page 314
# Scraping page 315...
#    → Found 20 jobs on page 315
# Scraping page 316...
#    → Found 20 jobs on page 316
# Scraping page 317...
#    → Found 20 jobs on page 317
# Scraping page 318...
#    → Found 20 jobs on page 318
# Scraping page 319...
#    → Found 20 jobs on page 319
# Scraping page 320...
#    → Found 20 jobs on page 320
# Scraping page 321...
#    → Found 20 jobs on page 321
# Scraping page 322...
#    → Found 20 jobs on page 322
# Scraping page 323...
#    → Found 20 jobs on page 323
# Scraping page 324...
#    → Found 20 jobs on page 324
# Scraping page 325...
#    → Found 20 jobs on page 325
# Scraping page 326...
#    → Found 20 jobs on page 326
# Scraping page 327...
#    → Found 20 jobs on page 327
# Scraping page 328...
#    → Found 20 jobs on page 328
# Scraping page 329...
#    → Found 20 jobs on page 329
# Scraping page 330...
#    → Found 20 jobs on page 330
# Scraping page 331...
#    → Found 20 jobs on page 331
# Scraping page 332...
#    → Found 20 jobs on page 332
# Scraping page 333...
#    → Found 20 jobs on page 333
# Scraping page 334...
#    → Found 20 jobs on page 334
# Scraping page 335...
#    → Found 20 jobs on page 335
# Scraping page 336...
#    → Found 20 jobs on page 336
# Scraping page 337...
#    → Found 20 jobs on page 337
# Scraping page 338...
#    → Found 20 jobs on page 338
# Scraping page 339...
#    → Found 20 jobs on page 339
# Scraping page 340...
#    → Found 20 jobs on page 340
# Scraping page 341...
#    → Found 20 jobs on page 341
# Scraping page 342...
#    → Found 20 jobs on page 342
# Scraping page 343...
#    → Found 20 jobs on page 343
# Scraping page 344...
#    → Found 20 jobs on page 344
# Scraping page 345...
#    → Found 20 jobs on page 345
# Scraping page 346...
#    → Found 20 jobs on page 346
# Scraping page 347...
#    → Found 20 jobs on page 347
# Scraping page 348...
#    → Found 20 jobs on page 348
# Scraping page 349...
#    → Found 20 jobs on page 349
# Scraping page 350...
#    → Found 20 jobs on page 350
# Scraping page 351...
#    → Found 20 jobs on page 351
# Scraping page 352...
#    → Found 20 jobs on page 352
# Scraping page 353...
#    → Found 20 jobs on page 353
# Scraping page 354...
#    → Found 20 jobs on page 354
# Scraping page 355...
#    → Found 20 jobs on page 355
# Scraping page 356...
#    → Found 20 jobs on page 356
# Scraping page 357...
#    → Found 20 jobs on page 357
# Scraping page 358...
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# Cell In[2], line 102
#     100 # RUN THE SCRAPER
#     101 print("Starting full scrape — this will take 4–8 minutes for 400–500 jobs...")
# --> 102 asyncio.get_event_loop().run_until_complete(scrape_all_pages())
#     104 # Save to Excel
#     105 df = pd.DataFrame(all_jobs)
#
# File /opt/anaconda3/lib/python3.13/site-packages/nest_asyncio.py:98, in _patch_loop.<locals>.run_until_complete(self, future)
#      95 if not f.done():
#      96     raise RuntimeError(
#      97         'Event loop stopped before Future completed.')
# ---> 98 return f.result()
#
# File /opt/anaconda3/lib/python3.13/asyncio/futures.py:199, in Future.result(self)
#     197 self.__log_traceback = False
#     198 if self._exception is not None:
# --> 199     raise self._exception.with_traceback(self._exception_tb)
#     200 return self._result
#
# File /opt/anaconda3/lib/python3.13/asyncio/tasks.py:304, in Task.__step_run_and_handle_result(***failed resolving arguments***)
#     300 try:
#     301     if exc is None:
#     302         # We use the `send` method directly, because coroutines
#     303         # don't have `__iter__` and `__next__` methods.
# --> 304         result = coro.send(None)
#     305     else:
#     306         result = coro.throw(exc)
#
# Cell In[2], line 34, in scrape_all_pages()
#      31 url = f"https://www.naukri.com/data-analyst-data-analytics-data-analysis-data-visualization-data-cleansing-jobs?k=data%20analyst%2C%20data%20analytics%2C%20data%20analysis%2C%20data%20visualization%2C%20data%20cleansing&experience=0&ugTypeGid=12&jobPostType=1&glbl_qcrc=1018&glbl_qcrc=1020&pageNo={current_page}"
#      33 print(f"Scraping page {current_page}...")
# ---> 34 await page.goto(url, wait_until="domcontentloaded", timeout=60000)
#      36 try:
#      37     await page.wait_for_selector('a[title]', timeout=30000)  # any job title
#
# File /opt/anaconda3/lib/python3.13/site-packages/playwright/async_api/_generated.py:8992, in Page.goto(self, url, timeout, wait_until, referer)
#    8931 async def goto(
#    8932     self,
#    8933     url: str,
#    (...)
#    8939     referer: typing.Optional[str] = None,
#    8940 ) -> typing.Optional["Response"]:
#    8941     """Page.goto
#    8942
#    8943     Returns the main resource response. In case of multiple redirects, the navigation will resolve with the first
#    (...)
#    8988     Union[Response, None]
#    8989     """
#    8991     return mapping.from_impl_nullable(
# -> 8992         await self._impl_obj.goto(
#    8993             url=url, timeout=timeout, waitUntil=wait_until, referer=referer
#    8994         )
#    8995     )
#
# File /opt/anaconda3/lib/python3.13/site-packages/playwright/_impl/_page.py:555, in Page.goto(self, url, timeout, waitUntil, referer)
#     548 async def goto(
#     549     self,
#     550     url: str,
#    (...)
#     553     referer: str = None,
#     554 ) -> Optional[Response]:
# --> 555     return await self._main_frame.goto(**locals_to_params(locals()))
#
# File /opt/anaconda3/lib/python3.13/site-packages/playwright/_impl/_frame.py:153, in Frame.goto(self, url, timeout, waitUntil, referer)
#     143 async def goto(
#     144     self,
#     145     url: str,
#    (...)
#     148     referer: str = None,
#     149 ) -> Optional[Response]:
#     150     return cast(
#     151         Optional[Response],
#     152         from_nullable_channel(
# --> 153             await self._channel.send(
#     154                 "goto", self._navigation_timeout, locals_to_params(locals())
#     155             )
#     156         ),
#     157     )
#
# File /opt/anaconda3/lib/python3.13/site-packages/playwright/_impl/_connection.py:69, in Channel.send(self, method, timeout_calculator, params, is_internal, title)
#      61 async def send(
#      62     self,
#      63     method: str,
#    (...)
#      67     title: str = None,
#      68 ) -> Any:
# ---> 69     return await self._connection.wrap_api_call(
#      70         lambda: self._inner_send(method, timeout_calculator, params, False),
#      71         is_internal,
#      72         title,
#      73     )
#
# File /opt/anaconda3/lib/python3.13/site-packages/playwright/_impl/_connection.py:559, in Connection.wrap_api_call(self, cb, is_internal, title)
#     557     return await cb()
#     558 except Exception as error:
# --> 559     raise rewrite_error(error, f"{parsed_st['apiName']}: {error}") from None
#     560 finally:
#     561     self._api_zone.set(None)
#
# Error: Page.goto: net::ERR_NETWORK_CHANGED at https://www.naukri.com/data-analyst-data-analytics-data-analysis-data-visualization-data-cleansing-jobs?k=data%20analyst%2C%20data%20analytics%2C%20data%20analysis%2C%20data%20visualization%2C%20data%20cleansing&experience=0&ugTypeGid=12&jobPostType=1&glbl_qcrc=1018&glbl_qcrc=1020&pageNo=358
# Call log:
#   - navigating to "https://www.naukri.com/data-analyst-data-analytics-data-analysis-data-visualization-data-cleansing-jobs?k=data%20analyst%2C%20data%20analytics%2C%20data%20analysis%2C%20data%20visualization%2C%20data%20cleansing&experience=0&ugTypeGid=12&jobPostType=1&glbl_qcrc=1018&glbl_qcrc=1020&pageNo=358", waiting until "domcontentloaded"

# %%
import pandas as pd

# %%
df = pd.DataFrame(all_jobs)   
print(f"Raw scraped rows: {len(df)}")
# Out:
# Raw scraped rows: 7129

# %%
df
# Out:
#                   Job Title             Company  \
# 0       Data Science Intern  Neozeno Talent Llp
# 1       Data Analyst Intern              Voylla
# 2     Data Analytics Intern      Reliance Games
# 3       Data Science Intern             Cyfotok
# 4              Data Analyst         Also Energy
# ...                     ...                 ...
# 7124          Data engineer      Leading Client
# 7125         Data Scientist        ADQ Services
# 7126         Data Scientist     Syren Cloud Inc
# 7127         Data Scientist    Veniso Solutions
# 7128           Data Analyst              Apptad
#
#                                                Location Experience  \
# 0                                                Remote        N/A
# 1                                                Jaipur    0-1 Yrs
# 2                                                  Pune    0-1 Yrs
# 3                                            Coimbatore        N/A
# 4                          Noida, Gurugram, Delhi / NCR    0-2 Yrs
# ...                                                 ...        ...
# 7124                                          Hyderabad    4-6 Yrs
# 7125                                          Hyderabad    1-3 Yrs
# 7126                                          Hyderabad    3-6 Yrs
# 7127                                          Hyderabad    2-7 Yrs
# 7128  Prayagraj, Varanasi, Ghaziabad, Kanpur, Luckno...    0-3 Yrs
#
#              Salary                                               Link
# 0      15,000/month  https://www.naukri.com/job-listings-data-scien...
# 1     Not Disclosed  https://www.naukri.com/job-listings-data-analy...
# 2     Not Disclosed  https://www.naukri.com/job-listings-data-analy...
# 3            Unpaid  https://www.naukri.com/job-listings-data-scien...
# 4       4-5 Lacs PA  https://www.naukri.com/job-listings-data-analy...
# ...             ...                                                ...
# 7124  Not Disclosed  https://www.naukri.com/job-listings-data-engin...
# 7125  Not Disclosed  https://www.naukri.com/job-listings-data-scien...
# 7126  Not Disclosed  https://www.naukri.com/job-listings-data-scien...
# 7127  Not Disclosed  https://www.naukri.com/job-listings-data-scien...
# 7128  Not Disclosed  https://www.naukri.com/job-listings-data-analy...
#
# [7129 rows x 6 columns]

# %%
df.to_csv('naukri_jobs_codealpha.csv', index=False, encoding='utf-8')

# %%
df
# Out:
#                   Job Title             Company  \
# 0       Data Science Intern  Neozeno Talent Llp
# 1       Data Analyst Intern              Voylla
# 2     Data Analytics Intern      Reliance Games
# 3       Data Science Intern             Cyfotok
# 4              Data Analyst         Also Energy
# ...                     ...                 ...
# 7124          Data engineer      Leading Client
# 7125         Data Scientist        ADQ Services
# 7126         Data Scientist     Syren Cloud Inc
# 7127         Data Scientist    Veniso Solutions
# 7128           Data Analyst              Apptad
#
#                                                Location Experience  \
# 0                                                Remote        N/A
# 1                                                Jaipur    0-1 Yrs
# 2                                                  Pune    0-1 Yrs
# 3                                            Coimbatore        N/A
# 4                          Noida, Gurugram, Delhi / NCR    0-2 Yrs
# ...                                                 ...        ...
# 7124                                          Hyderabad    4-6 Yrs
# 7125                                          Hyderabad    1-3 Yrs
# 7126                                          Hyderabad    3-6 Yrs
# 7127                                          Hyderabad    2-7 Yrs
# 7128  Prayagraj, Varanasi, Ghaziabad, Kanpur, Luckno...    0-3 Yrs
#
#              Salary                                               Link
# 0      15,000/month  https://www.naukri.com/job-listings-data-scien...
# 1     Not Disclosed  https://www.naukri.com/job-listings-data-analy...
# 2     Not Disclosed  https://www.naukri.com/job-listings-data-analy...
# 3            Unpaid  https://www.naukri.com/job-listings-data-scien...
# 4       4-5 Lacs PA  https://www.naukri.com/job-listings-data-analy...
# ...             ...                                                ...
# 7124  Not Disclosed  https://www.naukri.com/job-listings-data-engin...
# 7125  Not Disclosed  https://www.naukri.com/job-listings-data-scien...
# 7126  Not Disclosed  https://www.naukri.com/job-listings-data-scien...
# 7127  Not Disclosed  https://www.naukri.com/job-listings-data-scien...
# 7128  Not Disclosed  https://www.naukri.com/job-listings-data-analy...
#
# [7129 rows x 6 columns]

# %%
df.duplicated().sum()
# Out:
# np.int64(4743)

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#                   Job Title             Company  \
# 0       Data Science Intern  Neozeno Talent Llp
# 1       Data Analyst Intern              Voylla
# 2     Data Analytics Intern      Reliance Games
# 3       Data Science Intern             Cyfotok
# 4              Data Analyst         Also Energy
# ...                     ...                 ...
# 2384          Data engineer      Leading Client
# 2385         Data Scientist        ADQ Services
# 2386         Data Scientist     Syren Cloud Inc
# 2387         Data Scientist    Veniso Solutions
# 2388           Data Analyst              Apptad
#
#                                                Location Experience  \
# 0                                                Remote        N/A
# 1                                                Jaipur    0-1 Yrs
# 2                                                  Pune    0-1 Yrs
# 3                                            Coimbatore        N/A
# 4                          Noida, Gurugram, Delhi / NCR    0-2 Yrs
# ...                                                 ...        ...
# 2384                                          Hyderabad    4-6 Yrs
# 2385                                          Hyderabad    1-3 Yrs
# 2386                                          Hyderabad    3-6 Yrs
# 2387                                          Hyderabad    2-7 Yrs
# 2388  Prayagraj, Varanasi, Ghaziabad, Kanpur, Luckno...    0-3 Yrs
#
#              Salary                                               Link
# 0      15,000/month  https://www.naukri.com/job-listings-data-scien...
# 1     Not Disclosed  https://www.naukri.com/job-listings-data-analy...
# 2     Not Disclosed  https://www.naukri.com/job-listings-data-analy...
# 3            Unpaid  https://www.naukri.com/job-listings-data-scien...
# 4       4-5 Lacs PA  https://www.naukri.com/job-listings-data-analy...
# ...             ...                                                ...
# 2384  Not Disclosed  https://www.naukri.com/job-listings-data-engin...
# 2385  Not Disclosed  https://www.naukri.com/job-listings-data-scien...
# 2386  Not Disclosed  https://www.naukri.com/job-listings-data-scien...
# 2387  Not Disclosed  https://www.naukri.com/job-listings-data-scien...
# 2388  Not Disclosed  https://www.naukri.com/job-listings-data-analy...
#
# [2386 rows x 6 columns]

# %%
df.shape
# Out:
# (2386, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2386 entries, 0 to 2388
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Job Title   2386 non-null   object
#  1   Company     2386 non-null   object
#  2   Location    2386 non-null   object
#  3   Experience  2386 non-null   object
#  4   Salary      2386 non-null   object
#  5   Link        2386 non-null   object
# dtypes: object(6)
# memory usage: 130.5+ KB

# %%
df['Job Title'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Company'].nunique()
# Out:
# 1256

# %%
df['Salary'].nunique()
# Out:
# 134
